# %%
import pandas as pd
import numpy as np
import copy
import os
import re
from netaddr import *
import ipaddress
import time
# Out:
# /home/k.goto/.pyenv/versions/3.6.7/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/k.goto/.pyenv/versions/3.6.7/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ### df読み込み

# %%
# route information
fr_file = "fullroute_20191030.0000"
dtyp = {"Peer ASN (ASN of the monitor)": "int16"}
rcc06_df = pd.read_csv(fr_file, delimiter = "|", names = ("BGP Protocol", "timestamp", "W/A/B", "Peer IP(address of the monitor)", "Peer ASN (ASN of the monitor)", "Prefix", "ASPath", "Origin Protocol"), dtype=dtyp)
# jp addresses
jp_file = "jp_cidr"
jp_df = pd.read_csv(jp_file, delimiter = "\t", names = ("cc (JP)", "IP block"))
# unallocated jp addresses
jpnic_pooled = "unallocated-jpnic-20191101.txt"
pooled_df = pd.read_csv(jpnic_pooled, header = None, names = ("IP block",))

# %% [markdown]
# ### /8ごとに経路とjpを比較し，共通部分をとる (保存処理を書いていないので次回以降実装)

# %%
# fr_file = "fullroute_20191030.0000"
# dtyp = {"Peer ASN (ASN of the monitor)": "int16"}
# rcc06_df = pd.read_csv(fr_file, delimiter = "|", names = ("BGP Protocol", "timestamp", "W/A/B", "Peer IP(address of the monitor)", "Peer ASN (ASN of the monitor)", "Prefix", "ASPath", "Origin Protocol"), dtype=dtyp)

del rcc06_df["BGP Protocol"], rcc06_df["timestamp"], rcc06_df["W/A/B"], \
    rcc06_df["Peer IP(address of the monitor)"], rcc06_df["Peer ASN (ASN of the monitor)"], \
    rcc06_df["ASPath"], rcc06_df["Origin Protocol"]

start = time.time()

scope_blocks = []
# /8ごとにjp_dfを切り取って回る
for i in range(1, 256):
    # i.***.***.***/?となる部分だけを拾う
    head = str(i) + "{1}\."
    jp_section = jp_df.applymap(lambda x: bool(re.match(head, x)))
    jp_sub_table = jp_df[jp_section]["IP block"].dropna()
    
    rcc_section = rcc06_df.applymap(lambda x: bool(re.match(head, x)))
    rcc_sub_table = rcc06_df[rcc_section]["Prefix"].dropna()
    
    scope_raw = set()
    for rcc_row in rcc_sub_table:
        n1 = IPSet()
        n1.add(IPNetwork(rcc_row))
    
        for jp_row in jp_sub_table:
            n2 = IPSet()
            n2.add(IPNetwork(jp_row))
            # n1とn2の共通部分
            intersection = n1 & n2
            scope_raw.add(str(intersection))
            
    scope = list(scope_raw)
    blocks = [x.replace("IPSet(['", "").replace("'])", "") for i, x in enumerate(scope_raw) if x != "IPSet([])"]
    scope_blocks.append(blocks) 
    print(f"{i}.0.0.0/8: {len(blocks)} blocks are in scope")

elapsed = time.time() - start

print(f"elapsed time: {elapsed/(60*60)} [h]")
# Out:
# 1.0.0.0/8: 285 blocks are in scope
# 2.0.0.0/8: 0 blocks are in scope
# 3.0.0.0/8: 0 blocks are in scope
# 4.0.0.0/8: 0 blocks are in scope
# 5.0.0.0/8: 4 blocks are in scope
# 6.0.0.0/8: 0 blocks are in scope
# 7.0.0.0/8: 0 blocks are in scope
# 8.0.0.0/8: 0 blocks are in scope
# 9.0.0.0/8: 0 blocks are in scope
# 10.0.0.0/8: 0 blocks are in scope
# 11.0.0.0/8: 0 blocks are in scope
# 12.0.0.0/8: 0 blocks are in scope
# 13.0.0.0/8: 0 blocks are in scope
# 14.0.0.0/8: 32 blocks are in scope
# 15.0.0.0/8: 0 blocks are in scope
# 16.0.0.0/8: 0 blocks are in scope
# 17.0.0.0/8: 0 blocks are in scope
# 18.0.0.0/8: 0 blocks are in scope
# 19.0.0.0/8: 0 blocks are in scope
# 20.0.0.0/8: 0 blocks are in scope
# 21.0.0.0/8: 0 blocks are in scope
# 22.0.0.0/8: 0 blocks are in scope
# 23.0.0.0/8: 1 blocks are in scope
# 24.0.0.0/8: 2 blocks are in scope
# 25.0.0.0/8: 0 blocks are in scope
# 26.0.0.0/8: 0 blocks are in scope
# 27.0.0.0/8: 200 blocks are in scope
# 28.0.0.0/8: 0 blocks are in scope
# 29.0.0.0/8: 0 blocks are in scope
# 30.0.0.0/8: 0 blocks are in scope
# 31.0.0.0/8: 0 blocks are in scope
# 32.0.0.0/8: 0 blocks are in scope
# 33.0.0.0/8: 0 blocks are in scope
# 34.0.0.0/8: 0 blocks are in scope
# 35.0.0.0/8: 0 blocks are in scope
# 36.0.0.0/8: 89 blocks are in scope
# 37.0.0.0/8: 0 blocks are in scope
# 38.0.0.0/8: 0 blocks are in scope
# 39.0.0.0/8: 3 blocks are in scope
# 40.0.0.0/8: 0 blocks are in scope
# 41.0.0.0/8: 0 blocks are in scope
# 42.0.0.0/8: 64 blocks are in scope
# 43.0.0.0/8: 64 blocks are in scope
# 44.0.0.0/8: 0 blocks are in scope
# 45.0.0.0/8: 52 blocks are in scope
# 46.0.0.0/8: 0 blocks are in scope
# 47.0.0.0/8: 0 blocks are in scope
# 48.0.0.0/8: 0 blocks are in scope
# 49.0.0.0/8: 389 blocks are in scope
# 50.0.0.0/8: 0 blocks are in scope
# 51.0.0.0/8: 0 blocks are in scope
# 52.0.0.0/8: 0 blocks are in scope
# 53.0.0.0/8: 0 blocks are in scope
# 54.0.0.0/8: 0 blocks are in scope
# 55.0.0.0/8: 0 blocks are in scope
# 56.0.0.0/8: 0 blocks are in scope
# 57.0.0.0/8: 0 blocks are in scope
# 58.0.0.0/8: 61 blocks are in scope
# 59.0.0.0/8: 78 blocks are in scope
# 60.0.0.0/8: 122 blocks are in scope
# 61.0.0.0/8: 351 blocks are in scope
# 62.0.0.0/8: 0 blocks are in scope
# 63.0.0.0/8: 0 blocks are in scope
# 64.0.0.0/8: 4 blocks are in scope
# 65.0.0.0/8: 4 blocks are in scope
# 66.0.0.0/8: 0 blocks are in scope
# 67.0.0.0/8: 0 blocks are in scope
# 68.0.0.0/8: 0 blocks are in scope
# 69.0.0.0/8: 1 blocks are in scope
# 70.0.0.0/8: 0 blocks are in scope
# 71.0.0.0/8: 0 blocks are in scope
# 72.0.0.0/8: 0 blocks are in scope
# 73.0.0.0/8: 0 blocks are in scope
# 74.0.0.0/8: 0 blocks are in scope
# 75.0.0.0/8: 0 blocks are in scope
# 76.0.0.0/8: 1 blocks are in scope
# 77.0.0.0/8: 0 blocks are in scope
# 78.0.0.0/8: 0 blocks are in scope
# 79.0.0.0/8: 0 blocks are in scope
# 80.0.0.0/8: 0 blocks are in scope
# 81.0.0.0/8: 1 blocks are in scope
# 82.0.0.0/8: 0 blocks are in scope
# 83.0.0.0/8: 0 blocks are in scope
# 84.0.0.0/8: 0 blocks are in scope
# 85.0.0.0/8: 0 blocks are in scope
# 86.0.0.0/8: 0 blocks are in scope
# 87.0.0.0/8: 0 blocks are in scope
# 88.0.0.0/8: 0 blocks are in scope
# 89.0.0.0/8: 0 blocks are in scope
# 90.0.0.0/8: 0 blocks are in scope
# 91.0.0.0/8: 0 blocks are in scope
# 92.0.0.0/8: 1 blocks are in scope
# 93.0.0.0/8: 0 blocks are in scope
# 94.0.0.0/8: 0 blocks are in scope
# 95.0.0.0/8: 0 blocks are in scope
# 96.0.0.0/8: 0 blocks are in scope
# 97.0.0.0/8: 0 blocks are in scope
# 98.0.0.0/8: 0 blocks are in scope
# 99.0.0.0/8: 0 blocks are in scope
# 100.0.0.0/8: 0 blocks are in scope
# 101.0.0.0/8: 48 blocks are in scope
# 102.0.0.0/8: 0 blocks are in scope
# 103.0.0.0/8: 786 blocks are in scope
# 104.0.0.0/8: 4 blocks are in scope
# 105.0.0.0/8: 0 blocks are in scope
# 106.0.0.0/8: 52 blocks are in scope
# 107.0.0.0/8: 1 blocks are in scope
# 108.0.0.0/8: 0 blocks are in scope
# 109.0.0.0/8: 1 blocks are in scope
# 110.0.0.0/8: 144 blocks are in scope
# 111.0.0.0/8: 122 blocks are in scope
# 112.0.0.0/8: 32 blocks are in scope
# 113.0.0.0/8: 109 blocks are in scope
# 114.0.0.0/8: 57 blocks are in scope
# 115.0.0.0/8: 80 blocks are in scope
# 116.0.0.0/8: 70 blocks are in scope
# 117.0.0.0/8: 64 blocks are in scope
# 118.0.0.0/8: 60 blocks are in scope
# 119.0.0.0/8: 164 blocks are in scope
# 120.0.0.0/8: 34 blocks are in scope
# 121.0.0.0/8: 47 blocks are in scope
# 122.0.0.0/8: 117 blocks are in scope
# 123.0.0.0/8: 43 blocks are in scope
# 124.0.0.0/8: 133 blocks are in scope
# 125.0.0.0/8: 131 blocks are in scope
# 126.0.0.0/8: 235 blocks are in scope
# 127.0.0.0/8: 0 blocks are in scope
# 128.0.0.0/8: 4 blocks are in scope
# 129.0.0.0/8: 4 blocks are in scope
# 130.0.0.0/8: 7 blocks are in scope
# 131.0.0.0/8: 7 blocks are in scope
# 132.0.0.0/8: 2 blocks are in scope
# 133.0.0.0/8: 517 blocks are in scope
# 134.0.0.0/8: 5 blocks are in scope
# 135.0.0.0/8: 0 blocks are in scope
# 136.0.0.0/8: 1 blocks are in scope
# 137.0.0.0/8: 6 blocks are in scope
# 138.0.0.0/8: 29 blocks are in scope
# 139.0.0.0/8: 8 blocks are in scope
# 140.0.0.0/8: 1 blocks are in scope
# 141.0.0.0/8: 0 blocks are in scope
# 142.0.0.0/8: 0 blocks are in scope
# 143.0.0.0/8: 10 blocks are in scope
# 144.0.0.0/8: 3 blocks are in scope
# 145.0.0.0/8: 0 blocks are in scope
# 146.0.0.0/8: 4 blocks are in scope
# 147.0.0.0/8: 17 blocks are in scope
# 148.0.0.0/8: 3 blocks are in scope
# 149.0.0.0/8: 10 blocks are in scope
# 150.0.0.0/8: 140 blocks are in scope
# 151.0.0.0/8: 0 blocks are in scope
# 152.0.0.0/8: 1 blocks are in scope
# 153.0.0.0/8: 82 blocks are in scope
# 154.0.0.0/8: 7 blocks are in scope
# 155.0.0.0/8: 0 blocks are in scope
# 156.0.0.0/8: 0 blocks are in scope
# 157.0.0.0/8: 225 blocks are in scope
# 158.0.0.0/8: 23 blocks are in scope
# 159.0.0.0/8: 6 blocks are in scope
# 160.0.0.0/8: 120 blocks are in scope
# 161.0.0.0/8: 1 blocks are in scope
# 162.0.0.0/8: 0 blocks are in scope
# 163.0.0.0/8: 131 blocks are in scope
# 164.0.0.0/8: 51 blocks are in scope
# 165.0.0.0/8: 39 blocks are in scope
# 166.0.0.0/8: 2 blocks are in scope
# 167.0.0.0/8: 1 blocks are in scope
# 168.0.0.0/8: 0 blocks are in scope
# 169.0.0.0/8: 0 blocks are in scope
# 170.0.0.0/8: 16 blocks are in scope
# 171.0.0.0/8: 1 blocks are in scope
# 172.0.0.0/8: 2 blocks are in scope
# 173.0.0.0/8: 0 blocks are in scope
# 174.0.0.0/8: 0 blocks are in scope
# 175.0.0.0/8: 54 blocks are in scope
# 176.0.0.0/8: 0 blocks are in scope
# 177.0.0.0/8: 0 blocks are in scope
# 178.0.0.0/8: 0 blocks are in scope
# 179.0.0.0/8: 0 blocks are in scope
# 180.0.0.0/8: 99 blocks are in scope
# 181.0.0.0/8: 0 blocks are in scope
# 182.0.0.0/8: 111 blocks are in scope
# 183.0.0.0/8: 120 blocks are in scope
# 184.0.0.0/8: 0 blocks are in scope
# 185.0.0.0/8: 0 blocks are in scope
# 186.0.0.0/8: 0 blocks are in scope
# 187.0.0.0/8: 0 blocks are in scope
# 188.0.0.0/8: 0 blocks are in scope
# 189.0.0.0/8: 0 blocks are in scope
# 190.0.0.0/8: 0 blocks are in scope
# 191.0.0.0/8: 0 blocks are in scope
# 192.0.0.0/8: 176 blocks are in scope
# 193.0.0.0/8: 5 blocks are in scope
# 194.0.0.0/8: 2 blocks are in scope
# 195.0.0.0/8: 0 blocks are in scope
# 196.0.0.0/8: 0 blocks are in scope
# 197.0.0.0/8: 0 blocks are in scope
# 198.0.0.0/8: 1 blocks are in scope
# 199.0.0.0/8: 0 blocks are in scope
# 200.0.0.0/8: 0 blocks are in scope
# 201.0.0.0/8: 0 blocks are in scope
# 202.0.0.0/8: 1529 blocks are in scope
# 203.0.0.0/8: 475 blocks are in scope
# 204.0.0.0/8: 0 blocks are in scope
# 205.0.0.0/8: 0 blocks are in scope
# 206.0.0.0/8: 1 blocks are in scope
# 207.0.0.0/8: 0 blocks are in scope
# 208.0.0.0/8: 1 blocks are in scope
# 209.0.0.0/8: 0 blocks are in scope
# 210.0.0.0/8: 627 blocks are in scope
# 211.0.0.0/8: 250 blocks are in scope
# 212.0.0.0/8: 0 blocks are in scope
# 213.0.0.0/8: 0 blocks are in scope
# 214.0.0.0/8: 0 blocks are in scope
# 215.0.0.0/8: 0 blocks are in scope
# 216.0.0.0/8: 5 blocks are in scope
# 217.0.0.0/8: 4 blocks are in scope
# 218.0.0.0/8: 218 blocks are in scope
# 219.0.0.0/8: 439 blocks are in scope
# 220.0.0.0/8: 247 blocks are in scope
# 221.0.0.0/8: 129 blocks are in scope
# 222.0.0.0/8: 33 blocks are in scope
# 223.0.0.0/8: 36 blocks are in scope
# 224.0.0.0/8: 0 blocks are in scope
# 225.0.0.0/8: 0 blocks are in scope
# 226.0.0.0/8: 0 blocks are in scope
# 227.0.0.0/8: 0 blocks are in scope
# 228.0.0.0/8: 0 blocks are in scope
# 229.0.0.0/8: 0 blocks are in scope
# 230.0.0.0/8: 0 blocks are in scope
# 231.0.0.0/8: 0 blocks are in scope
# 232.0.0.0/8: 0 blocks are in scope
# 233.0.0.0/8: 0 blocks are in scope
# 234.0.0.0/8: 0 blocks are in scope
# 235.0.0.0/8: 0 blocks are in scope
# 236.0.0.0/8: 0 blocks are in scope
# 237.0.0.0/8: 0 blocks are in scope
# 238.0.0.0/8: 0 blocks are in scope
# 239.0.0.0/8: 0 blocks are in scope
# 240.0.0.0/8: 0 blocks are in scope
# 241.0.0.0/8: 0 blocks are in scope
# 242.0.0.0/8: 0 blocks are in scope
# 243.0.0.0/8: 0 blocks are in scope
# 244.0.0.0/8: 0 blocks are in scope
# 245.0.0.0/8: 0 blocks are in scope
# 246.0.0.0/8: 0 blocks are in scope
# 247.0.0.0/8: 0 blocks are in scope
# 248.0.0.0/8: 0 blocks are in scope
# 249.0.0.0/8: 0 blocks are in scope
# 250.0.0.0/8: 0 blocks are in scope
# 251.0.0.0/8: 0 blocks are in scope
# 252.0.0.0/8: 0 blocks are in scope
# 253.0.0.0/8: 0 blocks are in scope
# 254.0.0.0/8: 0 blocks are in scope
# 255.0.0.0/8: 0 blocks are in scope
# elapsed time: 2.308443619277742 [h]

# %% [markdown]
# ### 次にその中でもEUへ未割り当てのものをとる; 共通部分をとる

# %%
sus_raw = set()
# regular expression of an ip address
ip_regex = "\d+\.\d+\.\d+\.\d+"

for block in scope_blocks:
    n1 = IPSet()
    n1.add(IPNetwork(block))
    for p_block in pooled_df.itertuples():
        n2 = IPSet()
        if ("-" in (p_block[1])): # *** - *** のような範囲での記述のエントリがある
            match = re.findall(ip_regex, p_block[1]) # returns a list of matched parts
            s1 = IPSet()
            s1.add(IPRange(match[0], match[1]))
            # n1とs1の共通部分
            intersection = n1 & s1
        else:
            n2.add(IPNetwork(str(p_block[1])))
            # n1とn2の共通部分
            intersection = n1 & n2
        sus_raw.add(str(intersection))

sus = list(sus_raw)
# 本来は正規表現でcidr部分だけを抽出したい
sus_blocks = [x.replace("IPSet(['", "").replace("'])", "") for i, x in enumerate(sus) if x != "IPSet([])"]
print(f"{len(sus_blocks)} blocks found")
# Out:
# 0 blocks found

# %%
sus_raw = set()
# regular expression of an ip address
ip_regex = "\d+\.\d+\.\d+\.\d+"

for blocks in scope_blocks:
    for bl in blocks:
        n1 = IPSet()
        n1.add(IPNetwork(bl))
        for p_block in pooled_df.itertuples():
            n2 = IPSet()
            if ("-" in (p_block[1])): # *** - *** のような範囲での記述のエントリがある
                match = re.findall(ip_regex, p_block[1]) # returns a list of matched parts
                s1 = IPSet()
                s1.add(IPRange(match[0], match[1]))
                # n1とs1の共通部分
                intersection = n1 & s1
            else:
                n2.add(IPNetwork(str(p_block[1])))
                # n1とn2の共通部分
                intersection = n1 & n2
            sus_raw.add(str(intersection))

sus = list(sus_raw)
cidr_regex = "\d+\.\d+\.\d+\.\d+/\d+"
sus_blocks = [re.findall(cidr_regex, x) for i, x in enumerate(sus) if x != "IPSet([])"]
print(sus_blocks)

# %% [markdown]
# # 試験的にマッチしそうなところだけ拾って実行

# %%
# fr_file = "fullroute_20191030.0000"
# dtyp = {"Peer ASN (ASN of the monitor)": "int16"}
# rcc06_df = pd.read_csv(fr_file, delimiter = "|", names = ("BGP Protocol", "timestamp", "W/A/B", "Peer IP(address of the monitor)", "Peer ASN (ASN of the monitor)", "Prefix", "ASPath", "Origin Protocol"), dtype=dtyp)

del rcc06_df["BGP Protocol"], rcc06_df["timestamp"], rcc06_df["W/A/B"], \
    rcc06_df["Peer IP(address of the monitor)"], rcc06_df["Peer ASN (ASN of the monitor)"], \
    rcc06_df["ASPath"], rcc06_df["Origin Protocol"]

start = time.time()

scope_blocks = []
# /8ごとにjp_dfを切り取って回る とりあえず実験に1-5だけ
for i in range(202, 203):
    # i.***.***.***/?となる部分だけを拾う
    head = str(i) + "{1}\."
    jp_section = jp_df.applymap(lambda x: bool(re.match(head, x)))
    jp_sub_table = jp_df[jp_section]["IP block"].dropna()
    
    rcc_section = rcc06_df.applymap(lambda x: bool(re.match(head, x)))
    rcc_sub_table = rcc06_df[rcc_section]["Prefix"].dropna()
    
    scope_raw = set()
    for rcc_row in rcc_sub_table:
        n1 = IPSet()
        n1.add(IPNetwork(rcc_row))
    
        for jp_row in jp_sub_table:
            n2 = IPSet()
            n2.add(IPNetwork(jp_row))
            # n1とn2の共通部分
            intersection = n1 & n2
            scope_raw.add(str(intersection))
            
    scope = list(scope_raw)
    blocks = [x.replace("IPSet(['", "").replace("'])", "") for i, x in enumerate(scope_raw) if x != "IPSet([])"]
    scope_blocks.append(blocks) 
    print(f"{i}.0.0.0/8: {len(blocks)} blocks are in scope")

elapsed = time.time() - start

print(f"elapsed time: {elapsed/(60*60)} [h]")
# Out:
# 202.0.0.0/8: 1529 blocks are in scope
# elapsed time: 0.28721652739577824 [h]

# %%
sus_raw = set()
# regular expression of an ip address
ip_regex = "\d+\.\d+\.\d+\.\d+"

for blocks in scope_blocks:
    for bl in blocks:
        n1 = IPSet()
        n1.add(IPNetwork(bl))
        for p_block in pooled_df.itertuples():
            n2 = IPSet()
            if ("-" in (p_block[1])): # *** - *** のような範囲での記述のエントリがある
                match = re.findall(ip_regex, p_block[1]) # returns a list of matched parts
                s1 = IPSet()
                s1.add(IPRange(match[0], match[1]))
                # n1とs1の共通部分
                intersection = n1 & s1
            else:
                n2.add(IPNetwork(str(p_block[1])))
                # n1とn2の共通部分
                intersection = n1 & n2
            sus_raw.add(str(intersection))

sus = list(sus_raw)
cidr_regex = "\d+\.\d+\.\d+\.\d+/\d+"
sus_blocks = [re.findall(cidr_regex, x) for i, x in enumerate(sus) if x != "IPSet([])"]
print(sus_blocks)
# Out:
# [['202.233.154.0/24']]

# %%
# pandasの表示行数の制限を変える
pd.options.display.max_rows = 3000

# %% [markdown]
# rcc06_dfのindex 127316 - 210960はIPv6 これ以外にもありそう

# %%
rcc06_df[127315:210961][["Prefix"]]
# Out:
#                  Prefix
# 127315       32.0.0.0/8
# 127316        2001::/32
# 127317        2001::/32
# 127318        2001::/32
# 127319  2001:4:112::/48
# ...                 ...
# 210956        240f::/24
# 210957    240f:100::/24
# 210958    240f:100::/24
# 210959    240f:100::/24
# 210960     36.16.0.0/12
#
# [83646 rows x 1 columns]

# %% [markdown]
# ## 元のデータフレーム

# %% [markdown]
# #### 経路情報

# %%
rcc06_df
# Out:
#         BGP Protocol          timestamp W/A/B Peer IP(address of the monitor)  \
# 0        TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.169
# 1        TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.185
# 2        TABLE_DUMP2  10/30/19 00:00:00     B                    202.249.2.20
# 3        TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.169
# 4        TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.185
# ...              ...                ...   ...                             ...
# 2571504  TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.185
# 2571505  TABLE_DUMP2  10/30/19 00:00:00     B                    202.249.2.20
# 2571506  TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.169
# 2571507  TABLE_DUMP2  10/30/19 00:00:00     B                   202.249.2.185
# 2571508  TABLE_DUMP2  10/30/19 00:00:00     B                    202.249.2.20
#
#          Peer ASN (ASN of the monitor)            Prefix  \
# 0                                 2497        1.0.0.0/24
# 1                                25152        1.0.0.0/24
# 2                                 4777        1.0.0.0/24
# 3                                 2497        1.0.4.0/22
# 4                                25152        1.0.4.0/22
# ...                                ...               ...
# 2571504                          25152  223.255.253.0/24
# 2571505                           4777  223.255.253.0/24
# 2571506                           2497  223.255.254.0/24
# 2571507                          25152  223.255.254.0/24
# 2571508                           4777  223.255.254.0/24
#
#                                                     ASPath Origin Protocol
# 0                                               2497 13335             IGP
# 1                                         25152 2914 13335             IGP
# 2                                               4777 13335             IGP
# 3                                    2497 4826 38803 56203             IGP
# 4                              25152 6939 4826 38803 56203             IGP
# ...                                                    ...             ...
# 2571504                              25152 2914 4134 58519             IGP
# 2571505                               4777 2516 4134 58519             IGP
# 2571506                               2497 7473 3758 55415             IGP
# 2571507  25152 6939 4657 55415 55415 55415 55415 55415 ...             IGP
# 2571508  4777 6939 4657 55415 55415 55415 55415 55415 5...             IGP
#
# [2571509 rows x 8 columns]

# %% [markdown]
# #### jpnicに割り振られたもの

# %%
jp_df
# Out:
#      cc (JP)          IP block
# 0         JP       1.0.16.0/20
# 1         JP       1.0.64.0/18
# 2         JP       1.1.64.0/18
# 3         JP        1.5.0.0/16
# 4         JP       1.21.0.0/16
# ...      ...               ...
# 2852      JP  223.223.160.0/21
# 2853      JP  223.223.208.0/21
# 2854      JP  223.223.224.0/19
# 2855      JP   223.252.64.0/19
# 2856      JP  223.252.112.0/20
#
# [2857 rows x 2 columns]

# %% [markdown]
# #### jpnicに割り振られたが，EUへは未割り当てのもの

# %%
pooled_df
# Out:
#                           IP block
# 0                    61.122.4.0/22
# 1                    61.122.8.0/21
# 2                   61.122.20.0/22
# 3                   61.122.24.0/21
# 4                   61.122.96.0/22
# 5                  61.122.100.0/22
# 6                  61.122.104.0/21
# 7                  61.122.192.0/20
# 8                  61.125.176.0/22
# 9                  61.125.180.0/22
# 10                 61.125.184.0/21
# 11                  61.195.80.0/20
# 12                   61.198.0.0/21
# 13                   61.198.8.0/21
# 14                  61.198.32.0/22
# 15                  61.198.36.0/22
# 16                  61.198.40.0/21
# 17                  61.206.48.0/22
# 18                  61.206.52.0/22
# 19                  61.206.56.0/21
# 20                  61.206.80.0/22
# 21                  61.206.84.0/22
# 22                  61.206.88.0/21
# 23                  61.211.64.0/20
# 24                  61.211.80.0/22
# 25                  61.211.84.0/22
# 26                  61.211.88.0/21
# 27                103.238.244.0/22
# 28                103.250.200.0/22
# 29                180.235.144.0/22
# 30                 202.208.96.0/20
# 31                 202.210.64.0/18
# 32                 202.211.96.0/20
# 33                 202.213.80.0/20
# 34                202.220.128.0/20
# 35                202.220.144.0/20
# 36                202.227.112.0/20
# 37                202.227.192.0/18
# 38                 202.228.64.0/18
# 39                 202.233.76.0/22
# 40                 202.233.88.0/22
# 41                 202.233.92.0/22
# 42                 202.233.96.0/22
# 43                202.233.100.0/22
# 44                202.233.104.0/22
# 45                202.233.108.0/22
# 46                202.233.112.0/22
# 47                202.233.116.0/22
# 48                202.233.120.0/22
# 49                202.233.124.0/22
# 50                202.233.128.0/18
# 51                 202.235.16.0/20
# 52                  203.141.0.0/20
# 53                 203.141.16.0/22
# 54                 203.141.20.0/22
# 55                 203.141.24.0/21
# 56                 203.141.64.0/20
# 57                 203.141.96.0/20
# 58                 203.179.96.0/20
# 59                203.179.112.0/20
# 60                203.179.144.0/20
# 61                203.179.160.0/20
# 62                203.179.176.0/20
# 63                203.181.128.0/18
# 64                  210.133.0.0/18
# 65                210.133.128.0/19
# 66                 210.134.32.0/20
# 67                210.134.148.0/22
# 68                210.134.152.0/21
# 69                  210.135.0.0/20
# 70                 210.135.16.0/20
# 71                 210.135.32.0/20
# 72                 210.135.48.0/20
# 73                210.135.128.0/20
# 74                210.135.240.0/20
# 75                  210.141.0.0/20
# 76                210.141.192.0/20
# 77                210.143.160.0/20
# 78                210.143.176.0/20
# 79                210.143.208.0/20
# 80                210.143.224.0/20
# 81                210.155.160.0/19
# 82                210.155.232.0/21
# 83                  210.156.4.0/22
# 84                  210.156.8.0/21
# 85                210.156.144.0/20
# 86                210.156.192.0/19
# 87                210.156.224.0/19
# 88                 210.157.32.0/20
# 89                 210.157.48.0/20
# 90                 210.157.96.0/20
# 91                210.157.112.0/20
# 92                210.157.160.0/19
# 93                 210.158.96.0/20
# 94                210.158.112.0/20
# 95                 210.159.32.0/19
# 96                 210.167.96.0/22
# 97                210.167.100.0/22
# 98                210.167.104.0/21
# 99                 210.171.68.0/22
# 100                210.171.72.0/21
# 101               210.171.176.0/20
# 102                210.173.96.0/22
# 103               210.173.100.0/22
# 104               210.173.104.0/21
# 105               210.173.112.0/20
# 106               210.173.128.0/22
# 107               210.173.132.0/22
# 108               210.173.136.0/21
# 109               210.191.224.0/19
# 110                210.198.32.0/19
# 111                210.199.64.0/22
# 112                210.199.68.0/22
# 113                210.199.72.0/21
# 114                210.229.36.0/22
# 115                210.229.40.0/21
# 116               210.231.224.0/19
# 117               210.233.128.0/19
# 118               210.233.192.0/19
# 119               210.233.224.0/20
# 120               210.236.192.0/22
# 121               210.236.196.0/22
# 122               210.236.200.0/21
# 123               210.249.224.0/22
# 124               210.249.228.0/22
# 125               210.249.232.0/21
# 126               210.249.240.0/20
# 127               210.251.128.0/20
# 128               210.251.144.0/20
# 129               210.251.224.0/22
# 130               210.251.228.0/22
# 131               210.251.232.0/21
# 132               210.255.128.0/20
# 133               210.255.144.0/20
# 134               210.255.224.0/22
# 135               210.255.228.0/22
# 136               210.255.232.0/21
# 137                 211.1.160.0/22
# 138                 211.1.164.0/22
# 139                 211.1.168.0/21
# 140                   211.9.0.0/19
# 141                 211.10.96.0/22
# 142                211.10.100.0/22
# 143                211.10.104.0/21
# 144                211.10.112.0/20
# 145                211.12.128.0/19
# 146                211.12.160.0/22
# 147                211.12.164.0/22
# 148                211.12.168.0/21
# 149                211.12.176.0/20
# 150                211.13.176.0/20
# 151                 211.15.64.0/22
# 152                 211.15.68.0/22
# 153                 211.15.72.0/21
# 154                 211.15.80.0/20
# 155                  211.19.0.0/22
# 156                  211.19.4.0/22
# 157                  211.19.8.0/21
# 158                211.19.128.0/19
# 159  211.120.252.0-211.120.254.255
# 160                 211.128.0.0/20
# 161               211.128.112.0/20
# 162                218.45.128.0/22
# 163                218.45.132.0/22
# 164                218.45.136.0/21
# 165                218.228.32.0/19
# 166                 219.99.48.0/20
# 167                219.100.73.0/24
# 168                219.100.74.0/23
# 169               219.100.253.0/24
# 170               219.100.254.0/23
# 171                219.103.80.0/20
# 172               219.105.128.0/20
# 173                219.109.16.0/20
# 174                219.124.64.0/20
# 175                 220.222.0.0/16
# 176                 220.223.0.0/16
